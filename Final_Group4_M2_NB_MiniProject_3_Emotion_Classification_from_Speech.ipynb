# %% [markdown]
# <a href="https://colab.research.google.com/github/gsandeep84/Projects/blob/main/Final_Group4_M2_NB_MiniProject_3_Emotion_Classification_from_Speech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Certification Program in Computational Data Science
# ## A program by IISc and TalentSprint
# ### Mini-Project: Speech Emotion Classification

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Build a model to recognize emotion from speech using Ensemble learning

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# At the end of the mini-project, you will be able to :
#
# * extract the features from audio data
# * implement ML classification algorithms individually and as Ensembles, to classify emotions
# * record the voice sample and test it with trained model

# %% [markdown]
# ## Dataset

# %% [markdown]
# **TESS Dataset**
#
# The first dataset chosen for this mini-project is the [TESS](https://dataverse.scholarsportal.info/dataset.xhtml?persistentId=doi:10.5683/SP2/E8H2MF) (Toronto emotional speech set) dataset. It contains 2880 files.  A set of 200 target words were spoken in the carrier phrase "Say the word _____' by two actresses and the sets were recorded in seven different emotions (anger, disgust, fear, happiness, pleasant surprise, sadness, and neutral). Both actresses spoke English as their first language, were university educated, and had musical training. Audiometric testing indicated that both actresses had thresholds within the normal range.

# %% [markdown]
# **Ravdess Dataset**
#
# The second dataset chosen for this mini-project is [Ravdess](https://zenodo.org/record/1188976#.YLczy4XivIU) (The Ryerson Audio-Visual Database of Emotional Speech and Song). This dataset contains 1440 files: 60 trials per actor x 24 actors = 1440. The RAVDESS contains 24 professional actors (12 female, 12 male), vocalizing two lexically-matched statements in a neutral North American accent. Speech emotions includes calm, happy, sad, angry, fearful, surprise, and disgust expressions. Each expression is produced at two levels of emotional intensity (normal, strong), with an additional neutral expression.
#
# **File naming convention**
#
# Each of the 1440 files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 03-01-06-01-02-01-12.wav). These identifiers define the stimulus characteristics:
#
# **Filename identifiers**
#
# * Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# * Vocal channel (01 = speech, 02 = song).
# * Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
# * Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
# * Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
# * Repetition (01 = 1st repetition, 02 = 2nd repetition).
# * Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: `03-01-06-01-02-01-12.wav`
#
#     - Audio-only - 03
#     - Speech - 01
#     - Fearful - 06
#     - Normal intensity - 01
#     - Statement "dogs" - 02
#     - 1st Repetition - 01
#     - 12th Actor - 12 Female, as the actor ID number is even.

# %% [markdown]
# ## Information

# %% [markdown]
# **Speech Emotion Recognition (SER)** is the task of recognizing the emotion from  speech, irrespective of the semantics. Humans can efficiently perform this task as a natural part of speech communication, however, the ability to conduct it automatically using programmable devices is a field of active research.
#
# Studies of automatic emotion recognition systems aim to create efficient, real-time methods of detecting the emotions of mobile phone users, call center operators and customers, car drivers, pilots, and many other human-machine communication users. Adding emotions to machines forms an important aspect of making machines appear and act in a human-like manner
#
# Lets gain familiarity with some of the audio based features that are commonly used for SER.
#
# **Mel scale** — The mel scale (derived from the word *melody*) is a perceptual scale of pitches judged by listeners to be equal in distance from one another. The reference point between this scale and normal frequency measurement is defined by assigning a perceptual pitch of 1000 mels to a 1000 Hz tone, 40 dB above the listener's threshold. Above about 500 Hz, increasingly large intervals are judged by listeners to produce equal pitch increments. Refer [here](https://towardsdatascience.com/learning-from-audio-the-mel-scale-mel-spectrograms-and-mel-frequency-cepstral-coefficients-f5752b6324a8) for more detailed information.
#
# **Pitch** — how high or low a sound is. It depends on frequency, higher pitch is high frequency
#
# **Frequency** — speed of vibration of sound, measures wave cycles per second
#
# **Chroma** — Representation for audio where spectrum is projected onto 12 bins representing the 12 distinct semitones (or chroma). Computed by summing the log frequency magnitude spectrum across octaves.
#
# **Fourier Transforms** — used to convert from time domain to frequency domain. Time domain shows how signal changes over time. Frequency domain shows how much of the signal lies within each given frequency band over a range of frequencies

# %% [markdown]
# **Librosa**
#
# [Librosa](https://librosa.org/doc/latest/index.html) is a Python package, built for speech and audio analytics. It provides modular functions that simplify working with audio data and help in achieving a wide range of applications such as identification of the personal characteristics of different individuals' voice samples, detecting emotions from audio samples etc.
#
# For further details on the Librosa package, refer [here](https://conference.scipy.org/proceedings/scipy2015/pdfs/brian_mcfee.pdf).

# %% [markdown]
# ## Grading = 10 Points

# %%
# !unzip /content/Records/Manjula.zip
# Out:
# Archive:  /content/Records/Manjula.zip
#    creating: Manjula/
#  extracting: Manjula/audio_2022-08-13_10-00-14_happy.wav
#   inflating: Manjula/audio_2022-08-13_10-02-58_happy.wav
#   inflating: Manjula/audio_2022-08-13_10-05-04_sad.wav
#   inflating: Manjula/audio_2022-08-13_10-06-36_sad.wav
#   inflating: Manjula/audio_2022-08-13_10-08-09_surprised.wav
#   inflating: Manjula/audio_2022-08-13_10-08-23_surprised.wav
#   inflating: Manjula/audio_2022-08-13_10-08-37_anger.wav
#  extracting: Manjula/audio_2022-08-13_10-08-50_anger.wav
#  extracting: Manjula/audio_2022-08-13_10-09-09_fear.wav
#   inflating: Manjula/audio_2022-08-13_10-09-20_fear.wav
#   inflating: Manjula/audio_2022-08-13_10-09-35_neutral.wav
#  extracting: Manjula/audio_2022-08-13_10-09-49_neutral.wav

# %%
#@title Download the datasets and install packages
# !wget -qq https://cdn.iisc.talentsprint.com/CDS/MiniProjects/Ravdess_Tess.zip
# !unzip -qq Ravdess_Tess.zip
# Install packages
# !pip -qq install librosa soundfile
# !pip -qq install wavio
print("Datasets downloaded successfully!")
# Out:
# Datasets downloaded successfully!

# %% [markdown]
# ### Import Neccesary Packages

# %%
import librosa
import librosa.display
import soundfile  
import os, glob, pickle
import numpy as np
import pandas as pd
import IPython.display as ipd
from matplotlib import pyplot as plt
from datetime import datetime
from IPython.display import Javascript
from google.colab import output
from base64 import b64decode
import warnings
warnings.filterwarnings('ignore')
# sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.ensemble import VotingClassifier
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ### Work-Flow
#
# * Load the TESS audio data and extract features and labels
#
# * Load the Ravdess audio data and extract features
#
# * Combine both the audio dataset features
#
# * Train and test the model with TESS + Ravdess Data
#
# * Record the team audio samples and add them to TESS + Ravdess data
#
# * Train and test the model with TESS + Ravdess + Team Recorded (combined) data
#
# * Test each of the models with live audio sample recording.

# %% [markdown]
# ### Load the Tess data and Ravdess data audio files (1 point)
#
# Hint: `glob.glob`

# %%
#Taken from 
#https://colab.research.google.com/drive/1yWvBCEreWHlJd4pYI3uYCbj2w5u3hhJJ#scrollTo=e594300b
def extract_feature(file_name):
    # load audio
    X, sample_rate = librosa.load(file_name)
    # apply stft()
    stft=np.abs(librosa.stft(X))
    result=np.array([])
    # compute mfcc
    mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
    # combine the features
    #print("mfccs is ",mfccs)
    result=np.hstack((result, mfccs))
    # compute chroma features and combine
    chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
    #print("chroma is ",chroma)
    result=np.hstack((result, chroma))
    # compute melspectrogram and combine
    mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
    #print("mel is ",mel)
    result=np.hstack((result, mel))
    #print("result is ",result)
    return result

# %%
df1 = pd.DataFrame()

# %%
# YOUR CODE HERE
def load_dataset(data_folder,extract_emotion,how_many=-1):
    df = pd.DataFrame()
    glob_expr=data_folder+'/*'
    for curFolder in glob.glob(glob_expr):
        print("Inside ",curFolder)
        if how_many != -1:
            if df.shape[0] >= how_many:
                break
        for wav_file in glob.glob(curFolder + '/*.wav'):
            print("Processing ",wav_file)
            if how_many != -1:
                if df.shape[0] >= how_many:
                    break
           
            print("current length is:: ",df.shape[0])
           
            wav_file_name = os.path.basename(wav_file)
            #print("Processing music file name",wav_file_name)
            emotion=extract_emotion(wav_file_name)
            
            feature = extract_feature(wav_file)
            row_object={'wav_file_name' : wav_file, 
                        'emotion' : emotion}
            feature_name_prefix='feature-'
            for x in range(len(feature)):
                feature_name=feature_name_prefix+str(x)
                row_object[feature_name]=feature[x]
             
            #print("row_object,",row_object)
            df = df.append(row_object,ignore_index = True)
    
    return df
        
def extract_emotion_ravdess(wav_file_name):
    emotions = {
                '01':'neutral',
                '02':'calm',
                '03':'happy',
                '04':'sad',
                '05':'angry',
                '06':'fear',
                '07':'disgust',
                '08':'surprised'
                }
    emotion = emotions[wav_file_name.split('-')[2]]
    print('ravdess emotion is ',emotion)
    return emotion

def extract_emotion_tess(wav_file_name):
    emotion=wav_file_name.split('_')[2].split('.')[0]
    print('tess emotion is ',emotion)
    return emotion

def extract_emotion_team(wav_file_name):
    print("team wav_file_name is ",wav_file_name)
    team_emotion=wav_file_name.split('_')[3].split('.')[0]
    print('group 4 team emotion is ',team_emotion)
    return team_emotion

def load_all_dataset(all_folder_details,how_many=-1):
    all_df = pd.DataFrame()
   
    for folder_detail in all_folder_details:
        print("Processing ",folder_detail.name)
        cur_df=load_dataset(folder_detail.name,folder_detail.emotion_function,how_many)
        all_df=pd.concat([all_df, cur_df],ignore_index=True)
        

   
    return all_df

# %%
class FolderDetails:
  def __init__(self, name, emotion_function):
    self.name = name
    self.emotion_function = emotion_function
  def __str__(self):
        return f'FolderDetails({self.name})'  

#
# Add as many as folders 
#

ravdess_data_folder='/content/ravdess/'
tess_data_folder='/content/Tess/'
group4_team_data_folder='/content/Records/'    
ravdess=FolderDetails(ravdess_data_folder,extract_emotion_ravdess)    
tess=FolderDetails(tess_data_folder,extract_emotion_tess)
#group4_team to be used later for training
group4_team=FolderDetails(group4_team_data_folder,extract_emotion_team)
all_folder_details=[]
all_folder_details.append(ravdess)
all_folder_details.append(tess)
#Make it -1 to load all.
how_many=100
all_df=load_all_dataset(all_folder_details,-1)
all_df.head()
all_df.iloc[0,0]
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing  /content/Tess/OAF_happy/OAF_far_happy.wav
# current length is::  1015
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_void_happy.wav
# current length is::  1016
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_rush_happy.wav
# current length is::  1017
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_mouse_happy.wav
# current length is::  1018
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_mill_happy.wav
# current length is::  1019
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_bath_happy.wav
# current length is::  1020
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_mess_happy.wav
# current length is::  1021
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_week_happy.wav
# current length is::  1022
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_food_happy.wav
# current length is::  1023
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_shawl_happy.wav
# current length is::  1024
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_fit_happy.wav
# current length is::  1025
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_sour_happy.wav
# current length is::  1026
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_get_happy.wav
# current length is::  1027
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_take_happy.wav
# current length is::  1028
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_hire_happy.wav
# current length is::  1029
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_rough_happy.wav
# current length is::  1030
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_hole_happy.wav
# current length is::  1031
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_cheek_happy.wav
# current length is::  1032
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_should_happy.wav
# current length is::  1033
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_lot_happy.wav
# current length is::  1034
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_door_happy.wav
# current length is::  1035
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_king_happy.wav
# current length is::  1036
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_hall_happy.wav
# current length is::  1037
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_mode_happy.wav
# current length is::  1038
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_hurl_happy.wav
# current length is::  1039
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_bone_happy.wav
# current length is::  1040
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_hush_happy.wav
# current length is::  1041
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_haze_happy.wav
# current length is::  1042
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_tire_happy.wav
# current length is::  1043
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_name_happy.wav
# current length is::  1044
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_bite_happy.wav
# current length is::  1045
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_page_happy.wav
# current length is::  1046
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_back_happy.wav
# current length is::  1047
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_thought_happy.wav
# current length is::  1048
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_rot_happy.wav
# current length is::  1049
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_laud_happy.wav
# current length is::  1050
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_choice_happy.wav
# current length is::  1051
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_luck_happy.wav
# current length is::  1052
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_doll_happy.wav
# current length is::  1053
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_pain_happy.wav
# current length is::  1054
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_fail_happy.wav
# current length is::  1055
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_seize_happy.wav
# current length is::  1056
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_soap_happy.wav
# current length is::  1057
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_fall_happy.wav
# current length is::  1058
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_perch_happy.wav
# current length is::  1059
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_whip_happy.wav
# current length is::  1060
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_yes_happy.wav
# current length is::  1061
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_dead_happy.wav
# current length is::  1062
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_good_happy.wav
# current length is::  1063
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_road_happy.wav
# current length is::  1064
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_merge_happy.wav
# current length is::  1065
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_chalk_happy.wav
# current length is::  1066
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_have_happy.wav
# current length is::  1067
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_raise_happy.wav
# current length is::  1068
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_mop_happy.wav
# current length is::  1069
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_jug_happy.wav
# current length is::  1070
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_tough_happy.wav
# current length is::  1071
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_life_happy.wav
# current length is::  1072
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_death_happy.wav
# current length is::  1073
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_came_happy.wav
# current length is::  1074
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_vine_happy.wav
# current length is::  1075
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_sub_happy.wav
# current length is::  1076
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_check_happy.wav
# current length is::  1077
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_base_happy.wav
# current length is::  1078
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_soup_happy.wav
# current length is::  1079
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_late_happy.wav
# current length is::  1080
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_burn_happy.wav
# current length is::  1081
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_match_happy.wav
# current length is::  1082
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_sail_happy.wav
# current length is::  1083
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_date_happy.wav
# current length is::  1084
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_tape_happy.wav
# current length is::  1085
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_rag_happy.wav
# current length is::  1086
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_raid_happy.wav
# current length is::  1087
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_such_happy.wav
# current length is::  1088
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_chair_happy.wav
# current length is::  1089
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_pike_happy.wav
# current length is::  1090
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_dog_happy.wav
# current length is::  1091
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_nag_happy.wav
# current length is::  1092
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_keg_happy.wav
# current length is::  1093
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_size_happy.wav
# current length is::  1094
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_young_happy.wav
# current length is::  1095
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_bought_happy.wav
# current length is::  1096
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_room_happy.wav
# current length is::  1097
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_third_happy.wav
# current length is::  1098
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_rose_happy.wav
# current length is::  1099
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_gun_happy.wav
# current length is::  1100
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_limb_happy.wav
# current length is::  1101
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_home_happy.wav
# current length is::  1102
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_yearn_happy.wav
# current length is::  1103
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_thumb_happy.wav
# current length is::  1104
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_shack_happy.wav
# current length is::  1105
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_voice_happy.wav
# current length is::  1106
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_which_happy.wav
# current length is::  1107
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_witch_happy.wav
# current length is::  1108
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_lid_happy.wav
# current length is::  1109
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_keen_happy.wav
# current length is::  1110
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_live_happy.wav
# current length is::  1111
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_judge_happy.wav
# current length is::  1112
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_sheep_happy.wav
# current length is::  1113
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_goal_happy.wav
# current length is::  1114
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_wag_happy.wav
# current length is::  1115
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_thin_happy.wav
# current length is::  1116
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_talk_happy.wav
# current length is::  1117
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_jar_happy.wav
# current length is::  1118
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_deep_happy.wav
# current length is::  1119
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_gaze_happy.wav
# current length is::  1120
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_vote_happy.wav
# current length is::  1121
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_goose_happy.wav
# current length is::  1122
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_search_happy.wav
# current length is::  1123
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_join_happy.wav
# current length is::  1124
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_wire_happy.wav
# current length is::  1125
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_mob_happy.wav
# current length is::  1126
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_sure_happy.wav
# current length is::  1127
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_boat_happy.wav
# current length is::  1128
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_lease_happy.wav
# current length is::  1129
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_bean_happy.wav
# current length is::  1130
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_dip_happy.wav
# current length is::  1131
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_cause_happy.wav
# current length is::  1132
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_fat_happy.wav
# current length is::  1133
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_team_happy.wav
# current length is::  1134
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_ripe_happy.wav
# current length is::  1135
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_gas_happy.wav
# current length is::  1136
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_beg_happy.wav
# current length is::  1137
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_hate_happy.wav
# current length is::  1138
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_kill_happy.wav
# current length is::  1139
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_read_happy.wav
# current length is::  1140
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_dodge_happy.wav
# current length is::  1141
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_germ_happy.wav
# current length is::  1142
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_bar_happy.wav
# current length is::  1143
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_gin_happy.wav
# current length is::  1144
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_five_happy.wav
# current length is::  1145
# tess emotion is  happy
# Processing  /content/Tess/OAF_happy/OAF_shirt_happy.wav
# current length is::  1146
# tess emotion is  happy
# Inside  /content/Tess/YAF_sad
# Processing  /content/Tess/YAF_sad/YAF_bought_sad.wav
# current length is::  1147
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_name_sad.wav
# current length is::  1148
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_hash_sad.wav
# current length is::  1149
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_food_sad.wav
# current length is::  1150
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_tell_sad.wav
# current length is::  1151
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_tire_sad.wav
# current length is::  1152
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_came_sad.wav
# current length is::  1153
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_ripe_sad.wav
# current length is::  1154
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_shirt_sad.wav
# current length is::  1155
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_sour_sad.wav
# current length is::  1156
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_dead_sad.wav
# current length is::  1157
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_thought_sad.wav
# current length is::  1158
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_yearn_sad.wav
# current length is::  1159
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_knock_sad.wav
# current length is::  1160
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_chalk_sad.wav
# current length is::  1161
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_hall_sad.wav
# current length is::  1162
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_ton_sad.wav
# current length is::  1163
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_near_sad.wav
# current length is::  1164
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_red_sad.wav
# current length is::  1165
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_pick_sad.wav
# current length is::  1166
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_chat_sad.wav
# current length is::  1167
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_voice_sad.wav
# current length is::  1168
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_should_sad.wav
# current length is::  1169
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_judge_sad.wav
# current length is::  1170
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_deep_sad.wav
# current length is::  1171
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_keen_sad.wav
# current length is::  1172
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_walk_sad.wav
# current length is::  1173
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_good_sad.wav
# current length is::  1174
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_shawl_sad.wav
# current length is::  1175
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_home_sad.wav
# current length is::  1176
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_wash_sad.wav
# current length is::  1177
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_fat_sad.wav
# current length is::  1178
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_page_sad.wav
# current length is::  1179
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_perch_sad.wav
# current length is::  1180
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_rough_sad.wav
# current length is::  1181
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_talk_sad.wav
# current length is::  1182
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_mouse_sad.wav
# current length is::  1183
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_pike_sad.wav
# current length is::  1184
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_pearl_sad.wav
# current length is::  1185
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_rose_sad.wav
# current length is::  1186
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_vote_sad.wav
# current length is::  1187
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_soup_sad.wav
# current length is::  1188
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_cool_sad.wav
# current length is::  1189
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_yes_sad.wav
# current length is::  1190
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_when_sad.wav
# current length is::  1191
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_beg_sad.wav
# current length is::  1192
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_boat_sad.wav
# current length is::  1193
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_date_sad.wav
# current length is::  1194
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_lot_sad.wav
# current length is::  1195
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_cause_sad.wav
# current length is::  1196
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_dip_sad.wav
# current length is::  1197
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_seize_sad.wav
# current length is::  1198
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_bean_sad.wav
# current length is::  1199
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_search_sad.wav
# current length is::  1200
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_life_sad.wav
# current length is::  1201
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_lid_sad.wav
# current length is::  1202
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_choice_sad.wav
# current length is::  1203
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_late_sad.wav
# current length is::  1204
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_bath_sad.wav
# current length is::  1205
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_mob_sad.wav
# current length is::  1206
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_wire_sad.wav
# current length is::  1207
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_lean_sad.wav
# current length is::  1208
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_sure_sad.wav
# current length is::  1209
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_road_sad.wav
# current length is::  1210
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_burn_sad.wav
# current length is::  1211
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_have_sad.wav
# current length is::  1212
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_pain_sad.wav
# current length is::  1213
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_fail_sad.wav
# current length is::  1214
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_size_sad.wav
# current length is::  1215
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_numb_sad.wav
# current length is::  1216
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_witch_sad.wav
# current length is::  1217
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_dog_sad.wav
# current length is::  1218
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_tough_sad.wav
# current length is::  1219
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_rain_sad.wav
# current length is::  1220
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_join_sad.wav
# current length is::  1221
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_kick_sad.wav
# current length is::  1222
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_nag_sad.wav
# current length is::  1223
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_fit_sad.wav
# current length is::  1224
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_wife_sad.wav
# current length is::  1225
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_long_sad.wav
# current length is::  1226
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_rat_sad.wav
# current length is::  1227
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_neat_sad.wav
# current length is::  1228
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_bar_sad.wav
# current length is::  1229
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_half_sad.wav
# current length is::  1230
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_shall_sad.wav
# current length is::  1231
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_puff_sad.wav
# current length is::  1232
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_mop_sad.wav
# current length is::  1233
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_note_sad.wav
# current length is::  1234
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_sheep_sad.wav
# current length is::  1235
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_thin_sad.wav
# current length is::  1236
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_hate_sad.wav
# current length is::  1237
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_phone_sad.wav
# current length is::  1238
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_third_sad.wav
# current length is::  1239
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_hire_sad.wav
# current length is::  1240
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_base_sad.wav
# current length is::  1241
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_whip_sad.wav
# current length is::  1242
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_vine_sad.wav
# current length is::  1243
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_rag_sad.wav
# current length is::  1244
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_wag_sad.wav
# current length is::  1245
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_tip_sad.wav
# current length is::  1246
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_bite_sad.wav
# current length is::  1247
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_which_sad.wav
# current length is::  1248
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_pad_sad.wav
# current length is::  1249
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_raid_sad.wav
# current length is::  1250
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_nice_sad.wav
# current length is::  1251
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_turn_sad.wav
# current length is::  1252
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_such_sad.wav
# current length is::  1253
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_get_sad.wav
# current length is::  1254
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_take_sad.wav
# current length is::  1255
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_reach_sad.wav
# current length is::  1256
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_limb_sad.wav
# current length is::  1257
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_gin_sad.wav
# current length is::  1258
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_dime_sad.wav
# current length is::  1259
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_far_sad.wav
# current length is::  1260
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_check_sad.wav
# current length is::  1261
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_hush_sad.wav
# current length is::  1262
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_mill_sad.wav
# current length is::  1263
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_youth_sad.wav
# current length is::  1264
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_death_sad.wav
# current length is::  1265
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_pool_sad.wav
# current length is::  1266
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_sell_sad.wav
# current length is::  1267
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_love_sad.wav
# current length is::  1268
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_luck_sad.wav
# current length is::  1269
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_gap_sad.wav
# current length is::  1270
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_chair_sad.wav
# current length is::  1271
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_keg_sad.wav
# current length is::  1272
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_hit_sad.wav
# current length is::  1273
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_shout_sad.wav
# current length is::  1274
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_mood_sad.wav
# current length is::  1275
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_lose_sad.wav
# current length is::  1276
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_goal_sad.wav
# current length is::  1277
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_learn_sad.wav
# current length is::  1278
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_king_sad.wav
# current length is::  1279
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_south_sad.wav
# current length is::  1280
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_kite_sad.wav
# current length is::  1281
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_tool_sad.wav
# current length is::  1282
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_raise_sad.wav
# current length is::  1283
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_mode_sad.wav
# current length is::  1284
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_keep_sad.wav
# current length is::  1285
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_dodge_sad.wav
# current length is::  1286
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_met_sad.wav
# current length is::  1287
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_rush_sad.wav
# current length is::  1288
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_jail_sad.wav
# current length is::  1289
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_jar_sad.wav
# current length is::  1290
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_mess_sad.wav
# current length is::  1291
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_jug_sad.wav
# current length is::  1292
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_team_sad.wav
# current length is::  1293
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_chief_sad.wav
# current length is::  1294
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_bone_sad.wav
# current length is::  1295
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_match_sad.wav
# current length is::  1296
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_ditch_sad.wav
# current length is::  1297
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_cheek_sad.wav
# current length is::  1298
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_merge_sad.wav
# current length is::  1299
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_juice_sad.wav
# current length is::  1300
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_pass_sad.wav
# current length is::  1301
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_cab_sad.wav
# current length is::  1302
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_lore_sad.wav
# current length is::  1303
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_calm_sad.wav
# current length is::  1304
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_gas_sad.wav
# current length is::  1305
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_room_sad.wav
# current length is::  1306
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_dab_sad.wav
# current length is::  1307
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_doll_sad.wav
# current length is::  1308
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_said_sad.wav
# current length is::  1309
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_door_sad.wav
# current length is::  1310
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_pole_sad.wav
# current length is::  1311
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_haze_sad.wav
# current length is::  1312
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_sail_sad.wav
# current length is::  1313
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_moon_sad.wav
# current length is::  1314
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_goose_sad.wav
# current length is::  1315
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_time_sad.wav
# current length is::  1316
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_five_sad.wav
# current length is::  1317
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_live_sad.wav
# current length is::  1318
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_book_sad.wav
# current length is::  1319
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_gun_sad.wav
# current length is::  1320
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_kill_sad.wav
# current length is::  1321
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_white_sad.wav
# current length is::  1322
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_peg_sad.wav
# current length is::  1323
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_gaze_sad.wav
# current length is::  1324
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_loaf_sad.wav
# current length is::  1325
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_soap_sad.wav
# current length is::  1326
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_read_sad.wav
# current length is::  1327
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_back_sad.wav
# current length is::  1328
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_hole_sad.wav
# current length is::  1329
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_rot_sad.wav
# current length is::  1330
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_make_sad.wav
# current length is::  1331
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_hurl_sad.wav
# current length is::  1332
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_lease_sad.wav
# current length is::  1333
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_ring_sad.wav
# current length is::  1334
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_fall_sad.wav
# current length is::  1335
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_void_sad.wav
# current length is::  1336
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_germ_sad.wav
# current length is::  1337
# tess emotion is  sad
# Processing  /content/Tess/YAF_sad/YAF_chain_sad.wav
# current length is::  1338
# tess emotion is  sad
# Inside  /content/Tess/OAF_Sad
# Processing  /content/Tess/OAF_Sad/OAF_beg_sad.wav
# current length is::  1339
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_youth_sad.wav
# current length is::  1340
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_came_sad.wav
# current length is::  1341
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_pole_sad.wav
# current length is::  1342
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_chalk_sad.wav
# current length is::  1343
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_merge_sad.wav
# current length is::  1344
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_rag_sad.wav
# current length is::  1345
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_sure_sad.wav
# current length is::  1346
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_sail_sad.wav
# current length is::  1347
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_bone_sad.wav
# current length is::  1348
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_loaf_sad.wav
# current length is::  1349
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_dead_sad.wav
# current length is::  1350
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_pass_sad.wav
# current length is::  1351
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_deep_sad.wav
# current length is::  1352
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_young_sad.wav
# current length is::  1353
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_keep_sad.wav
# current length is::  1354
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_whip_sad.wav
# current length is::  1355
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_gas_sad.wav
# current length is::  1356
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_choice_sad.wav
# current length is::  1357
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_when_sad.wav
# current length is::  1358
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_ton_sad.wav
# current length is::  1359
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_near_sad.wav
# current length is::  1360
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_fat_sad.wav
# current length is::  1361
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_rain_sad.wav
# current length is::  1362
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_size_sad.wav
# current length is::  1363
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_raid_sad.wav
# current length is::  1364
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_bite_sad.wav
# current length is::  1365
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_thin_sad.wav
# current length is::  1366
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_phone_sad.wav
# current length is::  1367
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_make_sad.wav
# current length is::  1368
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_burn_sad.wav
# current length is::  1369
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_hall_sad.wav
# current length is::  1370
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_learn_sad.wav
# current length is::  1371
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_pad_sad.wav
# current length is::  1372
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_have_sad.wav
# current length is::  1373
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_rot_sad.wav
# current length is::  1374
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_seize_sad.wav
# current length is::  1375
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_cheek_sad.wav
# current length is::  1376
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_voice_sad.wav
# current length is::  1377
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_hit_sad.wav
# current length is::  1378
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_kick_sad.wav
# current length is::  1379
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_match_sad.wav
# current length is::  1380
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_week_sad.wav
# current length is::  1381
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_half_sad.wav
# current length is::  1382
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_tire_sad.wav
# current length is::  1383
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_dodge_sad.wav
# current length is::  1384
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_sheep_sad.wav
# current length is::  1385
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_bean_sad.wav
# current length is::  1386
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_rush_sad.wav
# current length is::  1387
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_shout_sad.wav
# current length is::  1388
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_gun_sad.wav
# current length is::  1389
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_numb_sad.wav
# current length is::  1390
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_room_sad.wav
# current length is::  1391
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_ditch_sad.wav
# current length is::  1392
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_chair_sad.wav
# current length is::  1393
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_death_sad.wav
# current length is::  1394
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_keen_sad.wav
# current length is::  1395
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_void_sad.wav
# current length is::  1396
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_shirt_sad.wav
# current length is::  1397
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_wag_sad.wav
# current length is::  1398
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_third_sad.wav
# current length is::  1399
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_note_sad.wav
# current length is::  1400
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_search_sad.wav
# current length is::  1401
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_cab_sad.wav
# current length is::  1402
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_jug_sad.wav
# current length is::  1403
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_vine_sad.wav
# current length is::  1404
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_thumb_sad.wav
# current length is::  1405
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_fit_sad.wav
# current length is::  1406
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_back_sad.wav
# current length is::  1407
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_pool_sad.wav
# current length is::  1408
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_mess_sad.wav
# current length is::  1409
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_gin_sad.wav
# current length is::  1410
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_five_sad.wav
# current length is::  1411
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_cool_sad.wav
# current length is::  1412
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_bought_sad.wav
# current length is::  1413
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_date_sad.wav
# current length is::  1414
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_knock_sad.wav
# current length is::  1415
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_chat_sad.wav
# current length is::  1416
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_fail_sad.wav
# current length is::  1417
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_door_sad.wav
# current length is::  1418
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_yearn_sad.wav
# current length is::  1419
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_mill_sad.wav
# current length is::  1420
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_rat_sad.wav
# current length is::  1421
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_tape_sad.wav
# current length is::  1422
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_chain_sad.wav
# current length is::  1423
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_nice_sad.wav
# current length is::  1424
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_raise_sad.wav
# current length is::  1425
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_dab_sad.wav
# current length is::  1426
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_turn_sad.wav
# current length is::  1427
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_neat_sad.wav
# current length is::  1428
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_mop_sad.wav
# current length is::  1429
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_judge_sad.wav
# current length is::  1430
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_road_sad.wav
# current length is::  1431
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_kill_sad.wav
# current length is::  1432
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_such_sad.wav
# current length is::  1433
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_reach_sad.wav
# current length is::  1434
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_dog_sad.wav
# current length is::  1435
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_shawl_sad.wav
# current length is::  1436
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_gap_sad.wav
# current length is::  1437
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_calm_sad.wav
# current length is::  1438
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_should_sad.wav
# current length is::  1439
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_lean_sad.wav
# current length is::  1440
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_long_sad.wav
# current length is::  1441
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_red_sad.wav
# current length is::  1442
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_said_sad.wav
# current length is::  1443
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_love_sad.wav
# current length is::  1444
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_pick_sad.wav
# current length is::  1445
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_peg_sad.wav
# current length is::  1446
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_mob_sad.wav
# current length is::  1447
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_wash_sad.wav
# current length is::  1448
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_witch_sad.wav
# current length is::  1449
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_tell_sad.wav
# current length is::  1450
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_hire_sad.wav
# current length is::  1451
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_check_sad.wav
# current length is::  1452
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_luck_sad.wav
# current length is::  1453
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_join_sad.wav
# current length is::  1454
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_vote_sad.wav
# current length is::  1455
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_lid_sad.wav
# current length is::  1456
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_doll_sad.wav
# current length is::  1457
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_bar_sad.wav
# current length is::  1458
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_mouse_sad.wav
# current length is::  1459
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_sell_sad.wav
# current length is::  1460
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_goose_sad.wav
# current length is::  1461
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_ripe_sad.wav
# current length is::  1462
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_walk_sad.wav
# current length is::  1463
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_lose_sad.wav
# current length is::  1464
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_rose_sad.wav
# current length is::  1465
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_jar_sad.wav
# current length is::  1466
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_mode_sad.wav
# current length is::  1467
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_lore_sad.wav
# current length is::  1468
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_page_sad.wav
# current length is::  1469
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_food_sad.wav
# current length is::  1470
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_nag_sad.wav
# current length is::  1471
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_moon_sad.wav
# current length is::  1472
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_team_sad.wav
# current length is::  1473
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_kite_sad.wav
# current length is::  1474
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_yes_sad.wav
# current length is::  1475
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_haze_sad.wav
# current length is::  1476
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_wife_sad.wav
# current length is::  1477
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_home_sad.wav
# current length is::  1478
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_wheat_sad.wav
# current length is::  1479
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_hate_sad.wav
# current length is::  1480
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_which_sad.wav
# current length is::  1481
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_live_sad.wav
# current length is::  1482
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_base_sad.wav
# current length is::  1483
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_keg_sad.wav
# current length is::  1484
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_tough_sad.wav
# current length is::  1485
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_life_sad.wav
# current length is::  1486
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_white_sad.wav
# current length is::  1487
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_sour_sad.wav
# current length is::  1488
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_talk_sad.wav
# current length is::  1489
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_lease_sad.wav
# current length is::  1490
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_perch_sad.wav
# current length is::  1491
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_cause_sad.wav
# current length is::  1492
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_juice_sad.wav
# current length is::  1493
# tess emotion is  sad
# Processing  /content/Tess/OAF_Sad/OAF_soap_sad.wav
# current length is::  1494
# tess emotion is  sad
# ...
# Processing  /content/Tess/YAF_angry/YAF_seize_angry.wav
# current length is::  2526
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_yes_angry.wav
# current length is::  2527
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_laud_angry.wav
# current length is::  2528
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_knock_angry.wav
# current length is::  2529
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_thin_angry.wav
# current length is::  2530
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_death_angry.wav
# current length is::  2531
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_sell_angry.wav
# current length is::  2532
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_shawl_angry.wav
# current length is::  2533
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_mill_angry.wav
# current length is::  2534
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_sub_angry.wav
# current length is::  2535
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_ditch_angry.wav
# current length is::  2536
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_witch_angry.wav
# current length is::  2537
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_half_angry.wav
# current length is::  2538
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_read_angry.wav
# current length is::  2539
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_sail_angry.wav
# current length is::  2540
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_fat_angry.wav
# current length is::  2541
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_chair_angry.wav
# current length is::  2542
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_mess_angry.wav
# current length is::  2543
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_page_angry.wav
# current length is::  2544
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_home_angry.wav
# current length is::  2545
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_mouse_angry.wav
# current length is::  2546
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_tell_angry.wav
# current length is::  2547
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_hush_angry.wav
# current length is::  2548
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_shirt_angry.wav
# current length is::  2549
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_fail_angry.wav
# current length is::  2550
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_match_angry.wav
# current length is::  2551
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_rough_angry.wav
# current length is::  2552
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_goose_angry.wav
# current length is::  2553
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_ripe_angry.wav
# current length is::  2554
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_sure_angry.wav
# current length is::  2555
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_loaf_angry.wav
# current length is::  2556
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_jug_angry.wav
# current length is::  2557
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_fall_angry.wav
# current length is::  2558
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_mop_angry.wav
# current length is::  2559
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_beg_angry.wav
# current length is::  2560
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_nice_angry.wav
# current length is::  2561
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_hate_angry.wav
# current length is::  2562
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_back_angry.wav
# current length is::  2563
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_choice_angry.wav
# current length is::  2564
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_deep_angry.wav
# current length is::  2565
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_met_angry.wav
# current length is::  2566
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_shout_angry.wav
# current length is::  2567
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_learn_angry.wav
# current length is::  2568
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_south_angry.wav
# current length is::  2569
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_young_angry.wav
# current length is::  2570
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_base_angry.wav
# current length is::  2571
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_walk_angry.wav
# current length is::  2572
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_hash_angry.wav
# current length is::  2573
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_chat_angry.wav
# current length is::  2574
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_whip_angry.wav
# current length is::  2575
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_hall_angry.wav
# current length is::  2576
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_keen_angry.wav
# current length is::  2577
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_hit_angry.wav
# current length is::  2578
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_hurl_angry.wav
# current length is::  2579
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_sour_angry.wav
# current length is::  2580
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_pike_angry.wav
# current length is::  2581
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_calm_angry.wav
# current length is::  2582
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_dodge_angry.wav
# current length is::  2583
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_limb_angry.wav
# current length is::  2584
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_lose_angry.wav
# current length is::  2585
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_goal_angry.wav
# current length is::  2586
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_talk_angry.wav
# current length is::  2587
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_kick_angry.wav
# current length is::  2588
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_rot_angry.wav
# current length is::  2589
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_have_angry.wav
# current length is::  2590
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_vine_angry.wav
# current length is::  2591
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_search_angry.wav
# current length is::  2592
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_lid_angry.wav
# current length is::  2593
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_keg_angry.wav
# current length is::  2594
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_judge_angry.wav
# current length is::  2595
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_king_angry.wav
# current length is::  2596
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_voice_angry.wav
# current length is::  2597
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_peg_angry.wav
# current length is::  2598
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_pole_angry.wav
# current length is::  2599
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_bean_angry.wav
# current length is::  2600
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_rain_angry.wav
# current length is::  2601
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_road_angry.wav
# current length is::  2602
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_far_angry.wav
# current length is::  2603
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_take_angry.wav
# current length is::  2604
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_pick_angry.wav
# current length is::  2605
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_rush_angry.wav
# current length is::  2606
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_late_angry.wav
# current length is::  2607
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_book_angry.wav
# current length is::  2608
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_neat_angry.wav
# current length is::  2609
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_pain_angry.wav
# current length is::  2610
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_raise_angry.wav
# current length is::  2611
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_lore_angry.wav
# current length is::  2612
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_join_angry.wav
# current length is::  2613
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_good_angry.wav
# current length is::  2614
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_haze_angry.wav
# current length is::  2615
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_germ_angry.wav
# current length is::  2616
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_room_angry.wav
# current length is::  2617
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_yearn_angry.wav
# current length is::  2618
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_wife_angry.wav
# current length is::  2619
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_phone_angry.wav
# current length is::  2620
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_lease_angry.wav
# current length is::  2621
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_tough_angry.wav
# current length is::  2622
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_keep_angry.wav
# current length is::  2623
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_long_angry.wav
# current length is::  2624
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_five_angry.wav
# current length is::  2625
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_gas_angry.wav
# current length is::  2626
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_door_angry.wav
# current length is::  2627
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_chalk_angry.wav
# current length is::  2628
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_juice_angry.wav
# current length is::  2629
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_sheep_angry.wav
# current length is::  2630
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_void_angry.wav
# current length is::  2631
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_red_angry.wav
# current length is::  2632
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_love_angry.wav
# current length is::  2633
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_bar_angry.wav
# current length is::  2634
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_numb_angry.wav
# current length is::  2635
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_moon_angry.wav
# current length is::  2636
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_dog_angry.wav
# current length is::  2637
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_date_angry.wav
# current length is::  2638
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_get_angry.wav
# current length is::  2639
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_when_angry.wav
# current length is::  2640
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_pad_angry.wav
# current length is::  2641
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_dime_angry.wav
# current length is::  2642
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_bite_angry.wav
# current length is::  2643
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_rag_angry.wav
# current length is::  2644
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_shall_angry.wav
# current length is::  2645
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_lot_angry.wav
# current length is::  2646
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_vote_angry.wav
# current length is::  2647
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_tape_angry.wav
# current length is::  2648
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_perch_angry.wav
# current length is::  2649
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_name_angry.wav
# current length is::  2650
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_which_angry.wav
# current length is::  2651
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_came_angry.wav
# current length is::  2652
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_team_angry.wav
# current length is::  2653
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_such_angry.wav
# current length is::  2654
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_cheek_angry.wav
# current length is::  2655
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_wash_angry.wav
# current length is::  2656
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_ton_angry.wav
# current length is::  2657
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_pool_angry.wav
# current length is::  2658
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_third_angry.wav
# current length is::  2659
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_puff_angry.wav
# current length is::  2660
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_nag_angry.wav
# current length is::  2661
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_chain_angry.wav
# current length is::  2662
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_dab_angry.wav
# current length is::  2663
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_white_angry.wav
# current length is::  2664
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_fit_angry.wav
# current length is::  2665
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_rose_angry.wav
# current length is::  2666
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_make_angry.wav
# current length is::  2667
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_rat_angry.wav
# current length is::  2668
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_tip_angry.wav
# current length is::  2669
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_mob_angry.wav
# current length is::  2670
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_jail_angry.wav
# current length is::  2671
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_thought_angry.wav
# current length is::  2672
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_raid_angry.wav
# current length is::  2673
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_wag_angry.wav
# current length is::  2674
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_soap_angry.wav
# current length is::  2675
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_food_angry.wav
# current length is::  2676
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_wheat_angry.wav
# current length is::  2677
# tess emotion is  angry
# Processing  /content/Tess/YAF_angry/YAF_burn_angry.wav
# current length is::  2678
# tess emotion is  angry
# '/content/ravdess/Actor_10/03-01-08-01-02-02-10_surprised.wav'

# %% [markdown]
# #### Play the sample audio

# %%
all_df.iloc[0,0]
# Out:
# '/content/ravdess/Actor_10/03-01-08-01-02-02-10_surprised.wav'

# %%
# YOUR CODE HERE
n = np.random. randint(0,all_df.shape[0])
random_wav_file=all_df.iloc[n,0]
print(random_wav_file)
ipd.Audio(random_wav_file)
# Out:
# /content/ravdess/Actor_22/03-01-08-02-01-01-22_surprised.wav
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Data Exploration and Visualization (1 point)

# %% [markdown]
# #### Visualize the distribution of all the labels

# %%
# YOUR CODE HERE
#plt.plot(all_df.emotion)
print(all_df.emotion.value_counts())
sns.displot(all_df, x="emotion")
# Out:
# disgust      571
# surprised    569
# sad          562
# fear         561
# angry        561
# happy        557
# neutral      466
# Name: emotion, dtype: int64

# %% [markdown]
# #### Visualize sample audio signal using librosa

# %%
# YOUR CODE HERE
n = np.random. randint(0,all_df.shape[0])
random_wav_file=all_df.iloc[n,0]
print(random_wav_file)
random_music, sampling_rate = librosa.load(random_wav_file)
plt.figure(figsize=(15, 5))

# librosa.display.waveplot is used to plot waveform of amplitude vs time
librosa.display.waveplot(random_music, sr=sampling_rate)
# Out:
# /content/Tess/OAF_happy/OAF_reach_happy.wav

# %% [markdown]
# ### Feature extraction (2 points)
#
# Read one WAV file at a time using `Librosa`. An audio time series in the form of a 1-dimensional array for mono or 2-dimensional array for stereo, along with time sampling rate (which defines the length of the array), where the elements within each of the arrays represent the amplitude of the sound waves is returned by `librosa.load()` function. Refer to the supplementary notebook ('Audio feature extraction')
#
# To know more about Librosa, explore the [link](https://librosa.org/doc/latest/feature.html)

# %%
# YOUR CODE HERE
# Already done in the method load_all_dataset

# %% [markdown]
# #### Create a dictionary or a function to encode the emotions

# %%
# YOUR CODE HERE
# Already done in the method load_all_dataset

# %% [markdown]
# #### TESS data feature extraction

# %%
# YOUR CODE HERE
# Already done in the method load_all_dataset

# %% [markdown]
# #### Ravdess data feature extraction

# %%
# YOUR CODE HERE
# Already done in the method load_all_dataset

# %% [markdown]
# #### Save the features
#
# It is best advised to save the features in dataframe and maintain so that feature extraction step is not required to be performed every time.
#
# * Make a DataFrame with features and labels
#
# * Write dataframe into `.CSV` file and save it offline.

# %%
all_df.to_csv("all_data.csv")

# %%
# YOUR CODE HERE
all_saved_df=pd.read_csv("all_data.csv")
all_saved_df.head()
# Out:
#    Unnamed: 0                                      wav_file_name    emotion  \
# 0           0  /content/ravdess/Actor_10/03-01-08-01-02-02-10...  surprised
# 1           1  /content/ravdess/Actor_10/03-01-04-01-01-02-10...        sad
# 2           2  /content/ravdess/Actor_10/03-01-08-02-01-02-10...  surprised
# 3           3  /content/ravdess/Actor_10/03-01-03-01-02-02-10...      happy
# 4           4  /content/ravdess/Actor_10/03-01-06-01-02-02-10...       fear
#
#     feature-0  feature-1  feature-2  feature-3  feature-4  feature-5  \
# 0 -579.304260  73.996170  -7.420005  20.718863  -9.383029   2.693125
# 1 -611.454712  81.382256 -14.016294  24.023888  -7.985596   7.609945
# 2 -482.035187  49.152119 -24.271900  11.829809 -13.850123  -4.367917
# 3 -521.796997  68.446693 -26.124886  19.595650 -15.121578  -4.061383
# 4 -600.774719  67.085915  -8.814905  22.587708  -6.727428   9.228758
#
#    feature-6  ...   feature-170   feature-171   feature-172   feature-173  \
# 0 -13.922594  ...  1.729681e-13  1.409364e-13  1.189022e-13  1.031766e-13
# 1 -12.779557  ...  7.496798e-11  6.111337e-11  5.125681e-11  4.418788e-11
# 2 -14.766866  ...  3.735591e-14  3.091128e-14  2.678273e-14  2.455129e-14
# 3 -16.576546  ...  6.616500e-11  6.062553e-11  5.641089e-11  5.324709e-11
# 4 -11.633028  ...  1.309658e-12  1.178596e-12  1.080140e-12  1.005839e-12
#
#     feature-174   feature-175   feature-176   feature-177   feature-178  \
# 0  9.162788e-14  8.303843e-14  7.678215e-14  7.216952e-14  6.900960e-14
# 1  3.896853e-11  3.509586e-11  3.225878e-11  3.020182e-11  2.881758e-11
# 2  2.290197e-14  2.154637e-14  1.930728e-14  1.926691e-14  1.885234e-14
# 3  5.076706e-11  4.882884e-11  4.736716e-11  4.626181e-11  4.551436e-11
# 4  9.475083e-13  9.016931e-13  8.667086e-13  8.402030e-13  8.219395e-13
#
#     feature-179
# 0  6.715428e-14
# 1  2.799128e-11
# 2  1.831947e-14
# 3  4.504514e-11
# 4  8.105411e-13
#
# [5 rows x 183 columns]

# %%
sns.displot(all_saved_df, x="emotion")

# %% [markdown]
# #### Split the data into train and test

# %%
print(all_df.columns)
# Out:
# Index(['wav_file_name', 'emotion', 'feature-0', 'feature-1', 'feature-2',
#        'feature-3', 'feature-4', 'feature-5', 'feature-6', 'feature-7',
#        ...
#        'feature-170', 'feature-171', 'feature-172', 'feature-173',
#        'feature-174', 'feature-175', 'feature-176', 'feature-177',
#        'feature-178', 'feature-179'],
#       dtype='object', length=182)

# %%
# YOUR CODE HERE
def split_training_testing(df):
    X_train_idx,X_test_idx,y_train,y_test=train_test_split(df.index,df.emotion, test_size=0.2, random_state = 9)
    #print(df.iloc[X_train_idx,2:182])
    X_train=df.iloc[X_train_idx,2:182]
    X_test=df.iloc[X_test_idx,2:182]
    return X_train,X_test,y_train,y_test

# %% [markdown]
# ### Train the model with TESS + Ravdess data (2 points)
#
# * Apply different ML algorithms (eg. DecisionTree, RandomForest, etc.) and find the model with best performance

# %%
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 80, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [11,12]
# Minimum number of samples required to split a node
min_samples_split = [2, 5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
#bootstrap = [True]
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf
               }
print(param_grid)
def tune_hyperparam_random(df):
    X_train,X_test,y_train,y_test=split_training_testing(df)
    rfc = RandomForestClassifier()


    clf = RandomizedSearchCV(estimator = rfc, param_distributions = param_grid, cv = 10, verbose=2, n_jobs = 4,scoring='accuracy')

    clf.fit(X_train, y_train)

    print(clf.best_params_)

    print(clf.best_score_)
tune_hyperparam_random(all_df)
# Out:
# {'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72, 80], 'max_features': ['auto', 'sqrt'], 'max_depth': [11, 12], 'min_samples_split': [2, 5], 'min_samples_leaf': [1, 2]}
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'n_estimators': 56, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 12}
# 0.842060789373493

# %%
def tune_hyperparam_grid(df):
    X_train,X_test,y_train,y_test=split_training_testing(df)
    rfc = RandomForestClassifier(random_state=42)

    #forest_params = [{'max_depth': list(range(10, 15)), 'max_features': [10] }]
    #forest_params = [{'max_depth': list(range(5, 8)) }]
    forest_params = [{'max_depth': [12] ,'max_features': [10]}]
    #forest_params = [{'n_estimators':[700] }]
    print("RFC HYPER PARAMS",rfc.get_params())

    clf = GridSearchCV(rfc, forest_params, cv = 10, scoring='accuracy')

    clf.fit(X_train, y_train)

    print(clf.best_params_)

    print(clf.best_score_)


tune_hyperparam_grid(all_df)
# Out:
# RFC HYPER PARAMS {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
# {'max_depth': 12, 'max_features': 10}
# 0.8417350564744701

# %%
# YOUR CODE HERE
#Refer
#https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
# Instantiate LogisticRegression, KNN, SVC and VotingClassifier
def train_model(df,voting_strategy):
    X_train,X_test,y_train,y_test=split_training_testing(df)
    clazzifiers=[]
    log_clf = LogisticRegression(multi_class='multinomial', random_state=1)
    clazzifiers.append(log_clf)
    
    #rand_forest_clf = RandomForestClassifier(n_estimators=500,max_samples=100, random_state=1,max_depth=12,max_features=10)
    #rand_forest_clf = RandomForestClassifier(random_state=1,max_depth=12,max_features=10)
    rand_forest_clf = RandomForestClassifier(
                                             random_state=42,
                                             n_estimators=80,
                                             min_samples_split=2,
                                             min_samples_leaf=1,
                                             max_features='sqrt', 
                                             max_depth=12
                                            )
    
    clazzifiers.append(rand_forest_clf)
    gausian_clf = GaussianNB()
    #clazzifiers.append(gausian_clf)
    knn_clf = KNeighborsClassifier()
    #clazzifiers.append(knn_clf)
    svm_clf = SVC(probability= True)
    #clazzifiers.append(svm_clf)

    estimaters_list = [('lr', log_clf), ('knn', knn_clf), ('svc', svm_clf),('rf', rand_forest_clf), ('gnb', gausian_clf)]

    voting_clf = VotingClassifier(estimators= estimaters_list, voting=voting_strategy)
    clazzifiers.append(voting_clf)
    for clf in clazzifiers:
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
    return estimaters_list
print("....Using Soft Voting......")    
voting_strategy='soft'        
estimaters_list=train_model(all_df,voting_strategy)

print("....Using Hard Voting......")    
voting_strategy='hard'        
estimaters_list=train_model(all_df,voting_strategy)
# Out:
# ....Using Soft Voting......
# LogisticRegression 0.7506493506493507
# RandomForestClassifier 0.8675324675324675
# VotingClassifier 0.7766233766233767
# ....Using Hard Voting......
# LogisticRegression 0.7506493506493507
# RandomForestClassifier 0.8675324675324675
# VotingClassifier 0.8116883116883117

# %%
def test_a_random_sample(df,estimaters_list):
    n = np.random. randint(0,df.shape[0])
    print("random number is ",n)
    random_wav_file=df.iloc[n,0]
    print(random_wav_file)
    ipd.Audio(random_wav_file)
    X_test_random=df.iloc[n,2:182]
    y_test_random=df.iloc[n,1]
    #print("X_test_random ...",X_test_random)
    print("y_test_random ...",y_test_random)
    rand_forest_clf=estimaters_list[3][1]
    y_pred=rand_forest_clf.predict([X_test_random])
    print("prediction is ",y_pred)
test_a_random_sample(all_df,estimaters_list)
# Out:
# random number is  1720
# /content/Tess/YAF_fear/YAF_mess_fear.wav
# y_test_random ... fear
# prediction is  ['fear']

# %% [markdown]
# #### Apply the voting classifier

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Train the model with TESS + Ravdess + Team recorded data (4 points)
#
# * Record the audio samples (team data), extract features and combine with TESS + Ravdess data features
#   - Record and gather all the team data samples with proper naming convention in separate folder
#
#     **Hint:** Follow the supplementary notebook to record team data
#
#   - Each team member must record 2 samples for each emotion (Use similar sentences as given in TESS data)
#
# * Train the different ML algorithms and find the model with best performance

# %% [markdown]
# **Record Audio sample**
# Please use the below words for emotions.
#
#
#
#
#
#
#
#
#
#
#                 neutral
#                 calm
#                 happy
#                 sad
#                 angry
#                 fear
#                 disgust
#                 surprised

# %%
# Create a directory
user_folder="Records"
os.mkdir(user_folder)
user_folder="Records/Mano"
os.mkdir(user_folder)
print("Uncomment above for the first time execution")
# Out:
# Uncomment above for the first time execution

# %%
RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

def record(sec=3):
    emt = input("Enter emotion(label) to save the recording: ")
    print("Start speaking!")
    now = datetime.now()
    current_time = now.strftime("%Y-%m-%d_%H-%M-%S")
    display(Javascript(RECORD))
    s = output.eval_js('record(%d)' % (sec*1000))
    b = b64decode(s.split(',')[1])
    with open(user_folder+'/audio_'+current_time+"_"+emt+'.wav','wb') as f:
      f.write(b)
    return user_folder+'/audio_'+current_time+"_"+emt+'.wav'

# %%
# call the function to record a sample
record()

# %%
# change the path and listen to recorded audio sample
ipd.Audio("Records/Mano/audio_2022-08-13_09-58-49_sad.wav")

# %% [markdown]
# #### Load the team data

# %%
print(group4_team.name)
print(group4_team.emotion_function)
# Out:
# /content/Records/
# <function extract_emotion_team at 0x7f25e725a9e0>

# %%
# YOUR CODE HERE

cur_df=load_dataset(group4_team.name,group4_team.emotion_function,how_many=-1)

universal_df=pd.concat([all_df, cur_df],ignore_index=True)
print(all_df.shape)
print(universal_df.shape)

print("....Using Soft Voting......")    
voting_strategy='soft'        
estimaters_list=train_model(universal_df,voting_strategy)
test_a_random_sample(universal_df,estimaters_list)
# Out:
# Inside  /content/Records/Sindhu
# Processing  /content/Records/Sindhu/audio_2022-08-13_11-31-50_happy.wav
# current length is::  0
# team wav_file_name is  audio_2022-08-13_11-31-50_happy.wav
# group 4 team emotion is  happy
# Processing  /content/Records/Sindhu/audio_2022-08-13_11-34-16_calm.wav
# current length is::  1
# team wav_file_name is  audio_2022-08-13_11-34-16_calm.wav
# group 4 team emotion is  calm
# Processing  /content/Records/Sindhu/audio_2022-08-13_11-33-33_neutral.wav
# current length is::  2
# team wav_file_name is  audio_2022-08-13_11-33-33_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Sindhu/audio_2022-08-13_11-35-20_angry.wav
# current length is::  3
# team wav_file_name is  audio_2022-08-13_11-35-20_angry.wav
# group 4 team emotion is  angry
# Processing  /content/Records/Sindhu/audio_2022-08-13_11-36-35_fear.wav
# current length is::  4
# team wav_file_name is  audio_2022-08-13_11-36-35_fear.wav
# group 4 team emotion is  fear
# Processing  /content/Records/Sindhu/audio_2022-08-13_11-37-12_disgust.wav
# current length is::  5
# team wav_file_name is  audio_2022-08-13_11-37-12_disgust.wav
# group 4 team emotion is  disgust
# Processing  /content/Records/Sindhu/audio_2022-08-13_11-34-44_sad.wav
# current length is::  6
# team wav_file_name is  audio_2022-08-13_11-34-44_sad.wav
# group 4 team emotion is  sad
# Processing  /content/Records/Sindhu/audio_2022-08-13_11-36-00_surprised.wav
# current length is::  7
# team wav_file_name is  audio_2022-08-13_11-36-00_surprised.wav
# group 4 team emotion is  surprised
# Inside  /content/Records/Manjula
# Processing  /content/Records/Manjula/audio_2022-08-13_10-09-09_fear.wav
# current length is::  8
# team wav_file_name is  audio_2022-08-13_10-09-09_fear.wav
# group 4 team emotion is  fear
# Processing  /content/Records/Manjula/audio_2022-08-13_10-00-14_happy.wav
# current length is::  9
# team wav_file_name is  audio_2022-08-13_10-00-14_happy.wav
# group 4 team emotion is  happy
# Processing  /content/Records/Manjula/audio_2022-08-13_10-02-58_happy.wav
# current length is::  10
# team wav_file_name is  audio_2022-08-13_10-02-58_happy.wav
# group 4 team emotion is  happy
# Processing  /content/Records/Manjula/audio_2022-08-13_10-08-50_anger.wav
# current length is::  11
# team wav_file_name is  audio_2022-08-13_10-08-50_anger.wav
# group 4 team emotion is  anger
# Processing  /content/Records/Manjula/audio_2022-08-13_10-08-23_surprised.wav
# current length is::  12
# team wav_file_name is  audio_2022-08-13_10-08-23_surprised.wav
# group 4 team emotion is  surprised
# Processing  /content/Records/Manjula/audio_2022-08-13_10-05-04_sad.wav
# current length is::  13
# team wav_file_name is  audio_2022-08-13_10-05-04_sad.wav
# group 4 team emotion is  sad
# Processing  /content/Records/Manjula/audio_2022-08-13_10-06-36_sad.wav
# current length is::  14
# team wav_file_name is  audio_2022-08-13_10-06-36_sad.wav
# group 4 team emotion is  sad
# Processing  /content/Records/Manjula/audio_2022-08-13_10-09-20_fear.wav
# current length is::  15
# team wav_file_name is  audio_2022-08-13_10-09-20_fear.wav
# group 4 team emotion is  fear
# Processing  /content/Records/Manjula/audio_2022-08-13_10-08-09_surprised.wav
# current length is::  16
# team wav_file_name is  audio_2022-08-13_10-08-09_surprised.wav
# group 4 team emotion is  surprised
# Processing  /content/Records/Manjula/audio_2022-08-13_10-09-49_neutral.wav
# current length is::  17
# team wav_file_name is  audio_2022-08-13_10-09-49_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Manjula/audio_2022-08-13_10-09-35_neutral.wav
# current length is::  18
# team wav_file_name is  audio_2022-08-13_10-09-35_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Manjula/audio_2022-08-13_10-08-37_anger.wav
# current length is::  19
# team wav_file_name is  audio_2022-08-13_10-08-37_anger.wav
# group 4 team emotion is  anger
# Inside  /content/Records/Sridhar
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-15-08_neutral.wav
# current length is::  20
# team wav_file_name is  audio_2022-08-13_10-15-08_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-13-36_fearful.wav
# current length is::  21
# team wav_file_name is  audio_2022-08-13_10-13-36_fearful.wav
# group 4 team emotion is  fearful
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-14-49_neutral.wav
# current length is::  22
# team wav_file_name is  audio_2022-08-13_10-14-49_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-13-00_surprised.wav
# current length is::  23
# team wav_file_name is  audio_2022-08-13_10-13-00_surprised.wav
# group 4 team emotion is  surprised
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-11-41_angry.wav
# current length is::  24
# team wav_file_name is  audio_2022-08-13_10-11-41_angry.wav
# group 4 team emotion is  angry
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-12-32_surprised.wav
# current length is::  25
# team wav_file_name is  audio_2022-08-13_10-12-32_surprised.wav
# group 4 team emotion is  surprised
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-16-41_calm.wav
# current length is::  26
# team wav_file_name is  audio_2022-08-13_10-16-41_calm.wav
# group 4 team emotion is  calm
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-09-04_happy.wav
# current length is::  27
# team wav_file_name is  audio_2022-08-13_10-09-04_happy.wav
# group 4 team emotion is  happy
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-14-10_fearful.wav
# current length is::  28
# team wav_file_name is  audio_2022-08-13_10-14-10_fearful.wav
# group 4 team emotion is  fearful
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-11-15_angry.wav
# current length is::  29
# team wav_file_name is  audio_2022-08-13_10-11-15_angry.wav
# group 4 team emotion is  angry
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-16-56_calm.wav
# current length is::  30
# team wav_file_name is  audio_2022-08-13_10-16-56_calm.wav
# group 4 team emotion is  calm
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-14-31_neutral.wav
# current length is::  31
# team wav_file_name is  audio_2022-08-13_10-14-31_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-07-41_happy.wav
# current length is::  32
# team wav_file_name is  audio_2022-08-13_10-07-41_happy.wav
# group 4 team emotion is  happy
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-15-56_disgust.wav
# current length is::  33
# team wav_file_name is  audio_2022-08-13_10-15-56_disgust.wav
# group 4 team emotion is  disgust
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-16-10_disgust.wav
# current length is::  34
# team wav_file_name is  audio_2022-08-13_10-16-10_disgust.wav
# group 4 team emotion is  disgust
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-17-24_sad.wav
# current length is::  35
# team wav_file_name is  audio_2022-08-13_10-17-24_sad.wav
# group 4 team emotion is  sad
# Processing  /content/Records/Sridhar/audio_2022-08-13_10-17-36_sad.wav
# current length is::  36
# team wav_file_name is  audio_2022-08-13_10-17-36_sad.wav
# group 4 team emotion is  sad
# Inside  /content/Records/Soumya
# Processing  /content/Records/Soumya/audio_2022-08-13_09-50-22_fear.wav
# current length is::  37
# team wav_file_name is  audio_2022-08-13_09-50-22_fear.wav
# group 4 team emotion is  fear
# Processing  /content/Records/Soumya/audio_2022-08-13_09-43-58_sad.wav
# current length is::  38
# team wav_file_name is  audio_2022-08-13_09-43-58_sad.wav
# group 4 team emotion is  sad
# Processing  /content/Records/Soumya/audio_2022-08-13_09-45-46_angry.wav
# current length is::  39
# team wav_file_name is  audio_2022-08-13_09-45-46_angry.wav
# group 4 team emotion is  angry
# Processing  /content/Records/Soumya/audio_2022-08-13_09-43-35_calm.wav
# current length is::  40
# team wav_file_name is  audio_2022-08-13_09-43-35_calm.wav
# group 4 team emotion is  calm
# Processing  /content/Records/Soumya/audio_2022-08-13_09-43-14_neutral.wav
# current length is::  41
# team wav_file_name is  audio_2022-08-13_09-43-14_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Soumya/audio_2022-08-13_09-47-38_surprised.wav
# current length is::  42
# team wav_file_name is  audio_2022-08-13_09-47-38_surprised.wav
# group 4 team emotion is  surprised
# Processing  /content/Records/Soumya/audio_2022-08-13_09-42-05_happy.wav
# current length is::  43
# team wav_file_name is  audio_2022-08-13_09-42-05_happy.wav
# group 4 team emotion is  happy
# Processing  /content/Records/Soumya/audio_2022-08-13_09-51-47_disgust.wav
# current length is::  44
# team wav_file_name is  audio_2022-08-13_09-51-47_disgust.wav
# group 4 team emotion is  disgust
# Inside  /content/Records/Sandeep
# Processing  /content/Records/Sandeep/audio_2022-08-13_09-44-41_angry.wav
# current length is::  45
# team wav_file_name is  audio_2022-08-13_09-44-41_angry.wav
# group 4 team emotion is  angry
# Processing  /content/Records/Sandeep/audio_2022-08-13_09-47-59_sad.wav
# current length is::  46
# team wav_file_name is  audio_2022-08-13_09-47-59_sad.wav
# group 4 team emotion is  sad
# Processing  /content/Records/Sandeep/audio_2022-08-13_10-07-25_neutral.wav
# current length is::  47
# team wav_file_name is  audio_2022-08-13_10-07-25_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Sandeep/audio_2022-08-13_10-09-31_disgust.wav
# current length is::  48
# team wav_file_name is  audio_2022-08-13_10-09-31_disgust.wav
# group 4 team emotion is  disgust
# Processing  /content/Records/Sandeep/audio_2022-08-13_10-08-34_fear.wav
# current length is::  49
# team wav_file_name is  audio_2022-08-13_10-08-34_fear.wav
# group 4 team emotion is  fear
# Inside  /content/Records/Mano
# Processing  /content/Records/Mano/audio_2022-08-13_09-59-12_sad.wav
# current length is::  50
# team wav_file_name is  audio_2022-08-13_09-59-12_sad.wav
# group 4 team emotion is  sad
# Processing  /content/Records/Mano/audio_2022-08-13_09-59-39_disgust.wav
# current length is::  51
# team wav_file_name is  audio_2022-08-13_09-59-39_disgust.wav
# group 4 team emotion is  disgust
# Processing  /content/Records/Mano/audio_2022-08-13_09-57-09_happy.wav
# current length is::  52
# team wav_file_name is  audio_2022-08-13_09-57-09_happy.wav
# group 4 team emotion is  happy
# Processing  /content/Records/Mano/audio_2022-08-13_09-57-38_happy.wav
# current length is::  53
# team wav_file_name is  audio_2022-08-13_09-57-38_happy.wav
# group 4 team emotion is  happy
# Processing  /content/Records/Mano/audio_2022-08-13_09-58-49_sad.wav
# current length is::  54
# team wav_file_name is  audio_2022-08-13_09-58-49_sad.wav
# group 4 team emotion is  sad
# Processing  /content/Records/Mano/audio_2022-08-13_09-55-43_neutral.wav
# current length is::  55
# team wav_file_name is  audio_2022-08-13_09-55-43_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Mano/audio_2022-08-13_09-59-51_disgust.wav
# current length is::  56
# team wav_file_name is  audio_2022-08-13_09-59-51_disgust.wav
# group 4 team emotion is  disgust
# Processing  /content/Records/Mano/audio_2022-08-13_09-58-24_fear.wav
# current length is::  57
# team wav_file_name is  audio_2022-08-13_09-58-24_fear.wav
# group 4 team emotion is  fear
# Processing  /content/Records/Mano/audio_2022-08-13_09-56-12_neutral.wav
# current length is::  58
# team wav_file_name is  audio_2022-08-13_09-56-12_neutral.wav
# group 4 team emotion is  neutral
# Processing  /content/Records/Mano/audio_2022-08-13_09-57-58_fear.wav
# current length is::  59
# team wav_file_name is  audio_2022-08-13_09-57-58_fear.wav
# group 4 team emotion is  fear
# (3847, 182)
# (3907, 182)
# ....Using Soft Voting......
# LogisticRegression 0.7519181585677749
# RandomForestClassifier 0.8516624040920716
# VotingClassifier 0.7787723785166241
# random number is  680
# /content/ravdess/Actor_17/03-01-06-02-01-02-17_fear.wav
# y_test_random ... fear
# prediction is  ['fear']

# %% [markdown]
# #### Extracting features of team data and combine with TESS + Ravdess

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Train the different ML algorithms

# %%
# YOUR CODE HERE

# %% [markdown]
# #### Test the best working model with live audio recording

# %%
# choose the best working model and assign below
MODEL = estimaters_list[3][1]

# %%
#@title Speak the utterance and test
from IPython.display import Javascript
from google.colab import output
from base64 import b64decode
 
RECORD = """
const sleep  = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.srcElement.result)
  reader.readAsDataURL(blob)
})
var record = time => new Promise(async resolve => {
  stream = await navigator.mediaDevices.getUserMedia({ audio: true })
  recorder = new MediaRecorder(stream)
  chunks = []
  recorder.ondataavailable = e => chunks.push(e.data)
  recorder.start()
  await sleep(time)
  recorder.onstop = async ()=>{
    blob = new Blob(chunks)
    text = await b2text(blob)
    resolve(text)
  }
  recorder.stop()
})
"""

if not os.path.exists('ModelTesting/'):
    os.mkdir("ModelTesting/")
def record(sec=5):
    print("Start speaking!")
    now = datetime.now()
    current_time = now.strftime("%Y-%m-%d_%H-%M-%S")
    display(Javascript(RECORD))
    s = output.eval_js('record(%d)' % (sec*1000))
    b = b64decode(s.split(',')[1])
    with open('ModelTesting/audio_'+current_time+'.wav','wb') as f:
        f.write(b)
    return 'ModelTesting/audio_'+current_time+'.wav'
test_i = record()
pred = MODEL.predict(extract_feature(test_i).reshape(1,-1))
print(pred)
#idx_emotion = list(emotions.values()).index(pred[0])
#print(list(emotions.keys())[idx_emotion])
ipd.Audio(test_i)
# Out:
# Start speaking!
# ['angry']
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Report Analysis
#
# - Report the accuracy for 10 live samples using the model trained on TESS+Ravdess+Team data
# - Discuss with the team mentor regarding deep learnt audio features. Read a related article [here](https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=8805181).
